# %% [markdown]
# <a href="https://colab.research.google.com/github/hima722/IamHimanshi/blob/main/AirBnb_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name:**-*AirBnb Booking Analysis*
# ```

# %% [markdown]
# Project Type:EDA
#
# Name        :Himanshi Tyagi

# %% [markdown]
# # **Project Summary:**

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.
# This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values.
# Explore and analyze the data to discover key understandings (not limited to these) such as :
# What can we learn about different hosts and areas?
# What can we learn from predictions? (ex: locations, prices, reviews, etc)
# Which hosts are the busiest and why?
# Is there any noticeable difference of traffic among different areas and what could be the reason for it?

# %% [markdown]
# # **GitHub Links:**
# Name : Himanshi Tyagi
# Link :

# %%
# Importing useful libraries for EDA

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Airbnb NYC 2019.csv')

# %%
# Checking dimensions

df.shape
# Out:
# (48895, 16)

# %%
# Here are the first 5 rows of the dataset

df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Here are the last 5 rows of the dataset

df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
# Features (Column names of Dataset)

df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Checking Datatype

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# Finding missing values in Dataset

df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# There are 4 columns having missing values.(name, host_name, last_review and reviews_per_month)

# %%
df['name'].isnull().value_counts()
# Out:
# False    48879
# True        16
# Name: name, dtype: int64

# %%
df['host_name'].isnull().value_counts()
# Out:
# False    48874
# True        21
# Name: host_name, dtype: int64

# %%
df['last_review'].isnull().value_counts()
# Out:
# False    38843
# True     10052
# Name: last_review, dtype: int64

# %%
df['reviews_per_month'].isnull().value_counts()
# Out:
# False    38843
# True     10052
# Name: reviews_per_month, dtype: int64

# %% [markdown]
# ## **Handling** **missing** **values**

# %%
# Dropping null rows from 'name'

df.dropna(subset=['name'], inplace=True)

# %%
df.dropna(subset=['host_name'], inplace=True)

# %%
# Replacing all NaN values in 'reviews_per_month' with 0.0

df['reviews_per_month'] = df['reviews_per_month'].fillna(0.0)

# %%
# Replacing all NaN Dates in 'last_review' with end date of year

df['last_review'] = df['last_review'].fillna('2019-12-31')

# %%
# Checking for if there are any missing values left
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48858 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48858 non-null  int64
#  1   name                            48858 non-null  object
#  2   host_id                         48858 non-null  int64
#  3   host_name                       48858 non-null  object
#  4   neighbourhood_group             48858 non-null  object
#  5   neighbourhood                   48858 non-null  object
#  6   latitude                        48858 non-null  float64
#  7   longitude                       48858 non-null  float64
#  8   room_type                       48858 non-null  object
#  9   price                           48858 non-null  int64
#  10  minimum_nights                  48858 non-null  int64
#  11  number_of_reviews               48858 non-null  int64
# ...

# %% [markdown]
# There is no missing values left in data now we can do our analysis.

# %%
columns_to_keep = ['host_id', 'neighbourhood_group',
       'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'number_of_reviews', 'last_review',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365']

# %%
df = df[columns_to_keep]

# %% [markdown]
# **Visualizing and analysis**

# %%
# Correlation matrix

plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-26-bff8674b87b3>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# From the graph above we know that there is not a correlation between variables

# %% [markdown]
# **Reviews per month Vs Price**

# %%
# Observing price and reviews_per_month columns

a, ax = plt.subplots(figsize=(12, 5))
fig = sns.scatterplot(x='price', y='reviews_per_month', data=df)

# %% [markdown]
# **Number of reviews Vs Price**

# %%
# Observing price and number_of_reviews columns

a, ax = plt.subplots(figsize=(12, 5))
fig = sns.scatterplot(x='price', y='number_of_reviews', data=df)

# %% [markdown]
# By analysing above plots we can see that expensive listings has fewer reviews and less expensive lsitings has more reviews.

# %% [markdown]
# Analyzing **host_id**

# %%
df['host_id'] = df['host_id'].astype(str)
df['host_id'].describe()
# Out:
# count         48858
# unique        37425
# top       219517861
# freq            327
# Name: host_id, dtype: object

# %% [markdown]
# There are 37425 unique hosts

# %%
# Checking top host listings counts

df.host_id.value_counts().head()
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
# Name: host_id, dtype: int64

# %%
df.host_id.value_counts().head().plot(kind = 'bar',color=['blue', 'grey', 'grey', 'grey', 'grey'])
# Out:
# <Axes: >

# %% [markdown]
# 219517861 having the most listings count of 327.

# %% [markdown]
# **Room type**

# %%
# Analyzing listings

fig = plt.figure(figsize=(5,5), dpi=100)
df['room_type'].value_counts().plot(kind='pie',  autopct='%1.0f%%', startangle=360, fontsize=12)
# Out:
# <Axes: ylabel='room_type'>

# %%
df['room_type'].value_counts()
# Out:
# Entire home/apt    25393
# Private room       22306
# Shared room         1159
# Name: room_type, dtype: int64

# %% [markdown]
# The majority of the listings are **Entire home/apts** or **Private rooms**.

# %%
# Plotting room_type and neighbourhood_group on a bar-graph

plt.figure(figsize=(10,5))
sns.countplot(data = df, x = 'room_type', hue = 'neighbourhood_group')
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %% [markdown]
# Analyzing **neighbourhood_group**

# %%
# Plotting neighbourhood_group on a pie-chart

fig = plt.figure(figsize=(5,5), dpi=100)
df['neighbourhood_group'].value_counts().plot(kind='pie',  autopct='%1.0f%%', startangle=360, fontsize=12)
# Out:
# <Axes: ylabel='neighbourhood_group'>

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21643
# Brooklyn         20089
# Queens            5664
# Bronx             1089
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
df['neighbourhood_group'].describe()
# Out:
# count         48858
# unique            5
# top       Manhattan
# freq          21643
# Name: neighbourhood_group, dtype: object

# %%
df['neighbourhood'].value_counts().head()
# Out:
# Williamsburg          3917
# Bedford-Stuyvesant    3713
# Harlem                2655
# Bushwick              2462
# Upper West Side       1969
# Name: neighbourhood, dtype: int64

# %%
# Analyzing top busiest neighbourhood

fig = plt.figure(figsize=(5,5), dpi=100)
df['neighbourhood'].value_counts().head().plot(kind='pie',  autopct='%1.0f%%', startangle=360, fontsize=12)
# Out:
# <Axes: ylabel='neighbourhood'>

# %%
df.groupby('neighbourhood_group')['neighbourhood'].value_counts().head()
# Out:
# neighbourhood_group  neighbourhood
# Bronx                Kingsbridge      70
#                      Fordham          62
#                      Longwood         62
#                      Mott Haven       60
#                      Concourse        50
# Name: neighbourhood, dtype: int64

# %% [markdown]
# **Plotting Latitude and Longitude**

# %%
# Plotting neighbourhood_group by thier latitude & longitude on a scatter-plot

plt.figure(figsize=(10,6))
sns.scatterplot(x = df.longitude,y = df.latitude,hue=df.neighbourhood_group)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df.longitude, y=df.latitude, hue=df.room_type)

plt.show()

# %%
df.groupby('neighbourhood')['availability_365'].value_counts()
# Out:
# neighbourhood  availability_365
# Allerton       0                   5
#                90                  3
#                48                  2
#                57                  2
#                1                   1
#                                   ..
# Woodside       348                 1
#                353                 1
#                354                 1
#                362                 1
#                363                 1
# Name: availability_365, Length: 14181, dtype: int64

# %%
df["availability_365"].describe()
# Out:
# count    48895.000000
# mean       112.781327
# std        131.622289
# min          0.000000
# 25%          0.000000
# 50%         45.000000
# 75%        227.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %%
plotav=df["availability_365"].hist()
plotav
# Out:
# <Axes: >

# %%
df.groupby('neighbourhood_group')['availability_365'].mean()
# Out:
# neighbourhood_group
# Bronx            165.758937
# Brooklyn         100.232292
# Manhattan        111.979410
# Queens           144.451818
# Staten Island    199.678284
# Name: availability_365, dtype: float64

# %%
for i in range(1,11):
  print("Minimum nights: ",i)
  print("Count:",len(df[df['minimum_nights'] == i]))
# Out:
# Minimum nights:  1
# Count: 12720
# Minimum nights:  2
# Count: 11696
# Minimum nights:  3
# Count: 7999
# Minimum nights:  4
# Count: 3303
# Minimum nights:  5
# Count: 3034
# Minimum nights:  6
# Count: 752
# Minimum nights:  7
# Count: 2058
# Minimum nights:  8
# Count: 130
# Minimum nights:  9
# Count: 80
# Minimum nights:  10
# Count: 483

# %%
df['minimum_nights'].value_counts().head().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df.groupby('neighbourhood_group')['minimum_nights'].mean()
# Out:
# neighbourhood_group
# Bronx            4.560953
# Brooklyn         6.056556
# Manhattan        8.579151
# Queens           5.181433
# Staten Island    4.831099
# Name: minimum_nights, dtype: float64

# %% [markdown]
# **Price**
# **Average price of all neighbourhood_group**

# %%
# Calculating average prices of room_types in neighbourhood_group

nbhd_group_rtype_avg_price = df.groupby(['neighbourhood_group','room_type'])['price'].mean().reset_index()
nbhd_group_rtype_avg_price = nbhd_group_rtype_avg_price.sort_values(by='price', ascending=False)
nbhd_group_rtype_avg_price
# Out:
#    neighbourhood_group        room_type       price
# 6            Manhattan  Entire home/apt  249.239109
# 3             Brooklyn  Entire home/apt  178.327545
# 12       Staten Island  Entire home/apt  173.846591
# 9               Queens  Entire home/apt  147.050573
# 0                Bronx  Entire home/apt  127.506596
# 7            Manhattan     Private room  116.776622
# 8            Manhattan      Shared room   88.977083
# 4             Brooklyn     Private room   76.500099
# 10              Queens     Private room   71.762456
# 11              Queens      Shared room   69.020202
# 1                Bronx     Private room   66.788344
# 13       Staten Island     Private room   62.292553
# 2                Bronx      Shared room   59.800000
# 14       Staten Island      Shared room   57.444444
# 5             Brooklyn      Shared room   50.527845

# %%
df.groupby('neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
df.groupby('neighbourhood_group')['price'].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %%
avg_price = (df['price'].mean(),2)
print(avg_price)
# Out:
# (152.7206871868289, 2)

# %% [markdown]
# Average price of all neighbourhood is $152.74.

# %%
df.price.value_counts().head(10)
# Out:
# 100    2051
# 150    2047
# 50     1534
# 60     1458
# 200    1401
# 75     1370
# 80     1272
# 65     1190
# 70     1170
# 120    1130
# Name: price, dtype: int64

# %%
df.price.value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
# Categorizing Airbnb based on price range

df['price_range'] = df['price'].apply(lambda x : '0-100' if x <= 100 else ('101-200' if 100 < x <= 200 else '201+'))

# %%
df["price_range"].value_counts()
# Out:
# 0-100      23928
# 101-200    16583
# 201+        8384
# Name: price_range, dtype: int64

# %%
df["price_range"].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# **Conclusion**
#
#
# * Expensive listings has fewer reviews and less expensive has more reviews.
#
# * By analyzing host_id it shows that there are more than 37000 hosts available across NYC.
#
# *   Majority of booking wore done for Entire home/apt (25393),followed by private room(22306).
#
# *   Manhattan was the busiest neighbourhood group with 21643 entries,followed by Brooklyn with 20089 entries.
#
# *  Staten island has highest average availablity of 199 days were Mahattan has the least average availability of 112 days.
#
# *  Average price of neighbourhood group-
# *   Bronx was the cheapest with average price of $87,Manhattan was the most expensive with average price of $196.
# *   Average price of all neighbourhood group is $152.
# *  23909 listing choose the AirBnb whose price were less than $100,only 8378 listings booked AirBnb for more than $200.
